# %%
import cv2

# %%
#read an image
img=cv2.imread('F:\Data Science\Project-Face Recognition\mountain.jpg')

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(img)

# %% [markdown]
# #it differs from original image as opencv reads RGB image as BGR so red and blue channel gets swapped so we
# need to switch between two color spaces

# %%
newImg=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(newImg)

# %%
print(img)
# Out:
# [[[212 193 178]
#   [212 193 178]
#   [211 192 177]
#   ...
#   [207 195 185]
#   [209 197 187]
#   [212 200 190]]
#
#  [[212 193 178]
#   [212 193 178]
#   [212 193 178]
#   ...
#   [208 196 186]
#   [209 197 187]
#   [211 199 189]]
#
#  [[211 192 179]
#   [212 193 180]
#   [212 193 180]
#   ...
#   [209 196 188]
#   [210 197 189]
#   [210 197 189]]
#
#  ...
#
#  [[ 57 104  78]
#   [ 62 109  83]
#   [ 66 111  85]
#   ...
#   [ 35 116  91]
#   [ 40 119  92]
#   [ 43 124  97]]
#
#  [[ 59 108  80]
#   [ 65 114  86]
#   [ 69 117  89]
#   ...
#   [ 38 116  92]
#   [ 42 118  94]
#   [ 43 121  97]]
#
#  [[ 71 121  91]
#   [ 76 126  96]
#   [ 81 129 100]
#   ...
#   [ 42 118  94]
#   [ 43 119  95]
#   [ 42 118  94]]]

# %% [markdown]
# (0,0,0)->black
# (255,255,255)->white

# %%
print(newImg)
# Out:
# [[[178 193 212]
#   [178 193 212]
#   [177 192 211]
#   ...
#   [185 195 207]
#   [187 197 209]
#   [190 200 212]]
#
#  [[178 193 212]
#   [178 193 212]
#   [178 193 212]
#   ...
#   [186 196 208]
#   [187 197 209]
#   [189 199 211]]
#
#  [[179 192 211]
#   [180 193 212]
#   [180 193 212]
#   ...
#   [188 196 209]
#   [189 197 210]
#   [189 197 210]]
#
#  ...
#
#  [[ 78 104  57]
#   [ 83 109  62]
#   [ 85 111  66]
#   ...
#   [ 91 116  35]
#   [ 92 119  40]
#   [ 97 124  43]]
#
#  [[ 80 108  59]
#   [ 86 114  65]
#   [ 89 117  69]
#   ...
#   [ 92 116  38]
#   [ 94 118  42]
#   [ 97 121  43]]
#
#  [[ 91 121  71]
#   [ 96 126  76]
#   [100 129  81]
#   ...
#   [ 94 118  42]
#   [ 95 119  43]
#   [ 94 118  42]]]
